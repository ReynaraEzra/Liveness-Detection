# %% [markdown]
# # **Liveness Detection**
# By : Reynara Ezra Pratama
#
# Dataset : [CelebA Spoof](https://www.kaggle.com/attentionlayer241/celeba-spoof-for-face-antispoofing)

# %% [markdown]
# ## Import Library

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.1-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from ipython-autotime) (5.5.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (5.1.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->ipython-autotime) (0.7.0)
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.3.1
# time: 169 µs (started: 2021-10-27 05:57:28 +00:00)

# %%
import zipfile, os

local_zip = '/content/drive/MyDrive/Liveness Detection/Dataset 600 Images.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/Liveness Detection/Dataset')
zip_ref.close()
# Out:
# time: 2.41 s (started: 2021-10-27 05:57:28 +00:00)

# %%
print(os.listdir('/tmp/Liveness Detection/Dataset'))
# Out:
# ['Spoof', 'Live']
# time: 2.05 ms (started: 2021-10-27 05:57:30 +00:00)

# %% [markdown]
# ## Check Data

# %%
print('Number of Real Images : {}'.format(len(os.listdir('/tmp/Liveness Detection/Dataset/Live'))))
print('Number of Spoof Images : {}'.format(len(os.listdir('/tmp/Liveness Detection/Dataset/Spoof'))))
print('Total Images : {}'.format(
    len(os.listdir('/tmp/Liveness Detection/Dataset/Live')) + 
    len(os.listdir('/tmp/Liveness Detection/Dataset/Spoof')) 
    )
)
# Out:
# Number of Real Images : 300
# Number of Spoof Images : 300
# Total Images : 600
# time: 7.69 ms (started: 2021-10-27 05:57:30 +00:00)

# %% [markdown]
# ## Split Data Into Training and Testing

# %%
# !pip install split_folders
import splitfolders
splitfolders.ratio('/tmp/Liveness Detection/Dataset', 
                   '/tmp/Liveness Detection/Dataset/Data', 
                   seed=42, 
                   ratio=(0.8, 0.2))
# Out:
# Collecting split_folders
#   Downloading split_folders-0.4.3-py3-none-any.whl (7.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3
# Copying files: 600 files [00:00, 3751.14 files/s]
# time: 3.64 s (started: 2021-10-27 05:57:30 +00:00)

# %%
base_dir = '/tmp/Liveness Detection/Dataset/Data'
train_dir = os.path.join(base_dir, 'train') ## Train Dataset
validation_dir = os.path.join(base_dir, 'val') ## Validation Dataset
# Out:
# time: 3 ms (started: 2021-10-27 05:57:34 +00:00)

# %%
os.listdir('/tmp/Liveness Detection/Dataset/Data/train')
# Out:
# ['Spoof', 'Live']
# time: 7.27 ms (started: 2021-10-27 05:57:34 +00:00)

# %%
os.listdir('/tmp/Liveness Detection/Dataset/Data/val')
# Out:
# ['Spoof', 'Live']
# time: 7.63 ms (started: 2021-10-27 05:57:34 +00:00)

# %%
train_live_dir = os.path.join(train_dir, 'Live')
train_spoof_dir = os.path.join(train_dir, 'Spoof')

validation_live_dir = os.path.join(validation_dir, 'Live')
validation_spoof_dir = os.path.join(validation_dir, 'Spoof')
# Out:
# time: 8.39 ms (started: 2021-10-27 05:57:34 +00:00)

# %% [markdown]
# ## Check Train and Test Data

# %% [markdown]
# **Train Data**

# %%
total_size_train = (
    len(os.listdir('/tmp/Liveness Detection/Dataset/Data/train/Live')) + 
    len(os.listdir('/tmp/Liveness Detection/Dataset/Data/train/Spoof'))
)
print('Total Training Data is : {}'.format(total_size_train))
# Out:
# Total Training Data is : 480
# time: 6.12 ms (started: 2021-10-27 05:57:34 +00:00)

# %% [markdown]
# **Test Data**

# %%
total_size_test = (
    len(os.listdir('/tmp/Liveness Detection/Dataset/Data/val/Live')) + 
    len(os.listdir('/tmp/Liveness Detection/Dataset/Data/val/Spoof'))
)
print('Total Testing Data is : {}'.format(total_size_test))
# Out:
# Total Testing Data is : 120
# time: 5.4 ms (started: 2021-10-27 05:57:34 +00:00)

# %% [markdown]
# ## Image Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.2,
    horizontal_flip = True,
    shear_range = 0.2,
    zoom_range = 0.2,
    fill_mode = 'nearest'
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150, 150),
    #batch_size = 128,
    class_mode = 'binary'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size = (150, 150),
    #batch_size = 128,
    class_mode = 'binary'
)
# Out:
# Found 480 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.
# time: 833 ms (started: 2021-10-27 05:57:34 +00:00)

# %% [markdown]
# ## Construct Model Using CNN

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# time: 5.81 s (started: 2021-10-27 05:57:35 +00:00)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________
# time: 5.22 ms (started: 2021-10-27 05:57:41 +00:00)

# %%
model.compile(
    loss = 'binary_crossentropy',
    optimizer = 'Adam',
    metrics = ['accuracy']
)
# Out:
# time: 22.7 ms (started: 2021-10-27 05:57:41 +00:00)

# %%
history = model.fit(
    train_generator,
    epochs = 50,
    #callbacks = [reduce_LR, stop_early],
    validation_data = validation_generator,
    verbose = 1
)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 37s 392ms/step - loss: 0.6530 - accuracy: 0.5979 - val_loss: 0.5455 - val_accuracy: 0.7667
# Epoch 2/50
# 15/15 [==============================] - 5s 362ms/step - loss: 0.4595 - accuracy: 0.7875 - val_loss: 0.5101 - val_accuracy: 0.7917
# Epoch 3/50
# 15/15 [==============================] - 5s 366ms/step - loss: 0.3520 - accuracy: 0.8604 - val_loss: 0.3792 - val_accuracy: 0.8667
# Epoch 4/50
# 15/15 [==============================] - 5s 363ms/step - loss: 0.2908 - accuracy: 0.8875 - val_loss: 0.4564 - val_accuracy: 0.8417
# Epoch 5/50
# 15/15 [==============================] - 6s 369ms/step - loss: 0.2672 - accuracy: 0.9062 - val_loss: 0.3106 - val_accuracy: 0.9083
# Epoch 6/50
# 15/15 [==============================] - 5s 363ms/step - loss: 0.2843 - accuracy: 0.8958 - val_loss: 0.3266 - val_accuracy: 0.8833
# Epoch 7/50
# 15/15 [==============================] - 5s 364ms/step - loss: 0.2464 - accuracy: 0.9083 - val_loss: 0.4504 - val_accuracy: 0.8083
# Epoch 8/50
# 15/15 [==============================] - 5s 363ms/step - loss: 0.2748 - accuracy: 0.8979 - val_loss: 0.2803 - val_accuracy: 0.9083
# Epoch 9/50
# 15/15 [==============================] - 5s 366ms/step - loss: 0.2525 - accuracy: 0.9062 - val_loss: 0.3727 - val_accuracy: 0.8583
# Epoch 10/50
# 15/15 [==============================] - 5s 366ms/step - loss: 0.2268 - accuracy: 0.9250 - val_loss: 0.2706 - val_accuracy: 0.9000
# Epoch 11/50
# 15/15 [==============================] - 6s 371ms/step - loss: 0.1753 - accuracy: 0.9354 - val_loss: 0.2396 - val_accuracy: 0.9333
# Epoch 12/50
# 15/15 [==============================] - 5s 368ms/step - loss: 0.1708 - accuracy: 0.9396 - val_loss: 0.3159 - val_accuracy: 0.9000
# Epoch 13/50
# 15/15 [==============================] - 6s 370ms/step - loss: 0
50
# 15/15 [==============================] - 6s 370ms/step - loss: 0.0886 - accuracy: 0.9667 - val_loss: 0.2326 - val_accuracy: 0.9417
# Epoch 36/50
# 15/15 [==============================] - 6s 368ms/step - loss: 0.0974 - accuracy: 0.9563 - val_loss: 0.3857 - val_accuracy: 0.8833
# Epoch 37/50
# 15/15 [==============================] - 6s 371ms/step - loss: 0.1048 - accuracy: 0.9625 - val_loss: 0.2970 - val_accuracy: 0.9500
# Epoch 38/50
# 15/15 [==============================] - 6s 368ms/step - loss: 0.0903 - accuracy: 0.9646 - val_loss: 0.2187 - val_accuracy: 0.9417
# Epoch 39/50
# 15/15 [==============================] - 5s 366ms/step - loss: 0.0765 - accuracy: 0.9646 - val_loss: 0.2319 - val_accuracy: 0.9333
# Epoch 40/50
# 15/15 [==============================] - 6s 370ms/step - loss: 0.1129 - accuracy: 0.9563 - val_loss: 0.2077 - val_accuracy: 0.9417
# Epoch 41/50
# 15/15 [==============================] - 6s 372ms/step - loss: 0.0871 - accuracy: 0.9625 - val_loss: 0.2653 - val_accuracy: 0.9500
# Epoch 42/50
# 15/15 [==============================] - 6s 368ms/step - loss: 0.0545 - accuracy: 0.9792 - val_loss: 0.3601 - val_accuracy: 0.9417
# Epoch 43/50
# 15/15 [==============================] - 6s 363ms/step - loss: 0.0558 - accuracy: 0.9792 - val_loss: 0.3028 - val_accuracy: 0.9500
# Epoch 44/50
# 15/15 [==============================] - 6s 370ms/step - loss: 0.0727 - accuracy: 0.9750 - val_loss: 0.4405 - val_accuracy: 0.9167
# Epoch 45/50
# 15/15 [==============================] - 6s 377ms/step - loss: 0.0623 - accuracy: 0.9792 - val_loss: 0.3958 - val_accuracy: 0.9583
# Epoch 46/50
# 15/15 [==============================] - 6s 370ms/step - loss: 0.0637 - accuracy: 0.9771 - val_loss: 0.2760 - val_accuracy: 0.9333
# Epoch 47/50
# 15/15 [==============================] - 6s 370ms/step - loss: 0.1181 - accuracy: 0.9500 - val_loss: 0.3516 - val_accuracy: 0.9333
# Epoch 48/50
# 15/15 [==============================] - 6s 375ms/step - loss: 0.0943 - accuracy: 0.9667 - val_loss: 0.2700 - val_accuracy: 0.9500
# Epoch 49/50
# 15/15 [==============================] - 5s 366ms/step - loss: 0.0731 - accuracy: 0.9750 - val_loss: 0.4529 - val_accuracy: 0.9333
# Epoch 50/50
# 15/15 [==============================] - 6s 370ms/step - loss: 0.0702 - accuracy: 0.9750 - val_loss: 0.5750 - val_accuracy: 0.9167
# time: 5min 18s (started: 2021-10-27 05:57:41 +00:00)

# %%
model_1 = tf.keras.models.Sequential([
# first CONV => RELU => CONV => RELU => POOL layer set                                   
  tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding="same", input_shape=(150, 150, 3)),
  #tf.keras.layers.BatchNormalization(1),
  tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding="same"),
  #tf.keras.layers.BatchNormalization(1),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Dropout(0.25),

# second CONV => RELU => CONV => RELU => POOL layer set
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding="same"),
  #tf.keras.layers.BatchNormalization(1),
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding="same"),
  #tf.keras.layers.BatchNormalization(1),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Dropout(0.25),

# first (and only) set of FC => RELU layers
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(64, activation='relu'),
  #tf.keras.layers.BatchNormalization(1),
  tf.keras.layers.Dropout(0.5), 

# softmax classifier
  tf.keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# time: 99.1 ms (started: 2021-10-27 06:02:59 +00:00)

# %%
model_1.compile(
    loss = 'binary_crossentropy',
    optimizer = 'Adam',
    metrics = ['accuracy']
)
# Out:
# time: 10.7 ms (started: 2021-10-27 06:02:59 +00:00)

# %%
history_1 = model_1.fit(
    train_generator,
    epochs = 50,
    #callbacks = [reduce_LR, stop_early],
    validation_data = validation_generator,
    verbose = 1
)
# Out:
# Epoch 21/50
# 15/15 [==============================] - 6s 378ms/step - loss: 0.1615 - accuracy: 0.9396 - val_loss: 0.3638 - val_accuracy: 0.9333
# Epoch 22/50
# 15/15 [==============================] - 6s 376ms/step - loss: 0.1701 - accuracy: 0.9396 - val_loss: 0.2418 - val_accuracy: 0.9333
# Epoch 23/50
# 15/15 [==============================] - 6s 369ms/step - loss: 0.1548 - accuracy: 0.9479 - val_loss: 0.3840 - val_accuracy: 0.9083
# Epoch 24/50
# 15/15 [==============================] - 6s 375ms/step - loss: 0.1286 - accuracy: 0.9604 - val_loss: 0.2960 - val_accuracy: 0.9250
# Epoch 25/50
# 15/15 [==============================] - 6s 378ms/step - loss: 0.1193 - accuracy: 0.9583 - val_loss: 0.3831 - val_accuracy: 0.9250
# Epoch 26/50
# 15/15 [==============================] - 6s 380ms/step - loss: 0.1373 - accuracy: 0.9521 - val_loss: 0.3175 - val_accuracy: 0.9333
# Epoch 27/50
# 15/15 [==============================] - 6s 380ms/step - loss: 0.1756 - accuracy: 0.9354 - val_loss: 0.3854 - val_accuracy: 0.9000
# Epoch 28/50
# 15/15 [==============================] - 6s 385ms/step - loss: 0.1867 - accuracy: 0.9292 - val_loss: 0.3014 - val_accuracy: 0.9250
# Epoch 29/50
# 15/15 [==============================] - 6s 383ms/step - loss: 0.1344 - accuracy: 0.9438 - val_loss: 0.4050 - val_accuracy: 0.9167
# Epoch 30/50
# 15/15 [==============================] - 6s 382ms/step - loss: 0.1649 - accuracy: 0.9438 - val_loss: 0.3936 - val_accuracy: 0.8667
# Epoch 31/50
# 15/15 [==============================] - 6s 383ms/step - loss: 0.1488 - accuracy: 0.9458 - val_loss: 0.2902 - val_accuracy: 0.9167
# Epoch 32/50
# 15/15 [==============================] - 6s 381ms/step - loss: 0.1333 - accuracy: 0.9479 - val_loss: 0.4654 - val_accuracy: 0.9083
# Epoch 33/50
# 15/15 [==============================] - 6s 379ms/step - loss: 0.1287 - accuracy: 0.9688 - val_loss: 0.2351 - val_accuracy: 0.9250
# Epoch 34/50
# 15/15 [==============================] - 6s 378ms/step - loss: 0.1344 - accuracy: 0.9479 - val_loss: 0.2834 - val_accuracy: 0.9167
# Epoch 35/50
# 15/15 [==============================] - 6s 379ms/step - loss: 0.1363 - accuracy: 0.9521 - val_loss: 0.3325 - val_accuracy: 0.9000
# Epoch 36/50
# 15/15 [==============================] - 6s 382ms/step - loss: 0.1584 - accuracy: 0.9458 - val_loss: 0.2380 - val_accuracy: 0.9417
# Epoch 37/50
# 15/15 [==============================] - 6s 383ms/step - loss: 0.1124 - accuracy: 0.9604 - val_loss: 0.3470 - val_accuracy: 0.9500
# Epoch 38/50
# 15/15 [==============================] - 6s 378ms/step - loss: 0.1220 - accuracy: 0.9563 - val_loss: 0.5825 - val_accuracy: 0.9417
# Epoch 39/50
# 15/15 [==============================] - 6s 379ms/step - loss: 0.1206 - accuracy: 0.9521 - val_loss: 0.4897 - val_accuracy: 0.9167
# Epoch 40/50
# 15/15 [==============================] - 6s 382ms/step - loss: 0.1129 - accuracy: 0.9563 - val_loss: 0.4315 - val_accuracy: 0.9333
# Epoch 41/50
# 15/15 [==============================] - 6s 381ms/step - loss: 0.0762 - accuracy: 0.9688 - val_loss: 0.3309 - val_accuracy: 0.9417
# Epoch 42/50
# 15/15 [==============================] - 6s 381ms/step - loss: 0.1069 - accuracy: 0.9583 - val_loss: 0.4411 - val_accuracy: 0.9250
# Epoch 43/50
# 15/15 [==============================] - 6s 379ms/step - loss: 0.1133 - accuracy: 0.9604 - val_loss: 0.4390 - val_accuracy: 0.9333
# Epoch 44/50
# 15/15 [==============================] - 6s 385ms/step - loss: 0.0899 - accuracy: 0.9667 - val_loss: 0.6045 - val_accuracy: 0.9417
# Epoch 45/50
# 15/15 [==============================] - 6s 383ms/step - loss: 0.1025 - accuracy: 0.9688 - val_loss: 0.3550 - val_accuracy: 0.9250
# Epoch 46/50
# 15/15 [==============================] - 6s 383ms/step - loss: 0.1678 - accuracy: 0.9292 - val_loss: 0.3626 - val_accuracy: 0.9333
# Epoch 47/50
# 15/15 [==============================] - 6s 383ms/step - loss: 0.1640 - accuracy: 0.9375 - val_loss: 0.6141 - val_accuracy: 0.9167
# Epoch 48/50
# 15/15 [==============================] - 6s 378ms/step - loss: 0.1733 - accuracy: 0.9417 - val_loss: 0.3720 - val_accuracy: 0.9000
# Epoch 49/50
# 15/15 [==============================] - 6s 385ms/step - loss: 0.1214 - accuracy: 0.9646 - val_loss: 0.6228 - val_accuracy: 0.9000
# Epoch 50/50
# 15/15 [==============================] - 6s 383ms/step - loss: 0.1833 - accuracy: 0.9250 - val_loss: 0.5653 - val_accuracy: 0.9083
# time: 4min 48s (started: 2021-10-27 06:02:59 +00:00)

# %% [markdown]
# ## Plot Model History

# %%
import matplotlib.pyplot as plt

def plot_accuracy(history):
  plt.figure(figsize=(18,5))
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  epochs = range(len(acc))
  plot_acc = plt.plot(epochs, acc, 'red', label='Training Accuracy')
  plot_val_acc = plt.plot(epochs, val_acc, 'blue', label='Validation Accuracy')
  plt.xlabel('Epoch', fontsize=15)
  plt.ylabel('Accuracy', fontsize=15)
  plt.title('Training and Validation Accuracy', fontsize=25)
  plt.legend(bbox_to_anchor=(1,1), loc='best')
  plt.grid()
  plt.show()

def plot_loss(history):
  plt.figure(figsize=(18,5))
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs = range(len(loss))
  plot_loss = plt.plot(epochs, loss, 'red', label='Training Loss')
  plot_val_loss = plt.plot(epochs, val_loss, 'blue', label='Validation Loss')
  plt.xlabel('Epoch', fontsize=15)
  plt.ylabel('Loss', fontsize=15)
  plt.title('Training and Validation Loss', fontsize=25)
  plt.legend(bbox_to_anchor=(1,1), loc='best')
  plt.grid()
  plt.show()
# Out:
# time: 26.2 ms (started: 2021-10-27 06:07:48 +00:00)

# %%
plot_accuracy(history)
# Out:
# time: 322 ms (started: 2021-10-27 06:07:48 +00:00)

# %%
plot_accuracy(history_1)
# Out:
# time: 273 ms (started: 2021-10-27 06:07:48 +00:00)

# %%
plot_loss(history)
# Out:
# time: 277 ms (started: 2021-10-27 06:07:48 +00:00)

# %%
plot_loss(history_1)
# Out:
# time: 339 ms (started: 2021-10-27 06:07:48 +00:00)

# %%
model.save('model.h5')
# Out:
# time: 108 ms (started: 2021-10-27 06:07:49 +00:00)

# %%
model_1.save('model_1.h5')
# Out:
# time: 94.8 ms (started: 2021-10-27 06:07:49 +00:00)
