# %% [markdown]
# <a href="https://colab.research.google.com/github/ReynaraEzra/Liveness-Detection/blob/main/Liveness%20Detection%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Liveness Detection**
# By : Reynara Ezra Pratama
#
# Dataset : [CelebA Spoof](https://www.kaggle.com/attentionlayer241/celeba-spoof-for-face-antispoofing)

# %% [markdown]
# ## Import Library

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0
# time: 1.6 ms (started: 2021-10-26 08:31:35 +00:00)

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Requirement already satisfied: ipython-autotime in /usr/local/lib/python3.7/dist-packages (0.3.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from ipython-autotime) (5.5.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (57.4.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (5.1.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.8.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->ipython-autotime) (0.7.0)
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 3.17 s (started: 2021-10-26 08:31:36 +00:00)

# %%
import zipfile, os

local_zip = '/content/drive/MyDrive/Liveness Detection/Dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/Liveness Detection/Dataset')
zip_ref.close()
# Out:
# time: 51.9 ms (started: 2021-10-26 08:31:39 +00:00)

# %%
print(os.listdir('/tmp/Liveness Detection/Dataset'))
# Out:
# ['Spoof', 'Live']
# time: 1.41 ms (started: 2021-10-26 08:31:40 +00:00)

# %% [markdown]
# ## Check Data

# %%
import os

print('Number of Real Images : {}'.format(len(os.listdir('/tmp/Liveness Detection/Dataset/Live'))))
print('Number of Spoof Images : {}'.format(len(os.listdir('/tmp/Liveness Detection/Dataset/Spoof'))))
print('Total Images : {}'.format(
    len(os.listdir('/tmp/Liveness Detection/Dataset/Live')) + 
    len(os.listdir('/tmp/Liveness Detection/Dataset/Spoof')) 
    )
)
# Out:
# Number of Real Images : 29
# Number of Spoof Images : 30
# Total Images : 59
# time: 4.1 ms (started: 2021-10-26 08:31:41 +00:00)

# %% [markdown]
# ## Split Data Into Training and Testing

# %%
# !pip install split_folders
# import splitfolders
# splitfolders.ratio('/content/drive/MyDrive/Liveness Detection', 
#                    '/content/drive/MyDrive/Liveness Detection/Data', 
#                    seed=1, 
#                    ratio=(0.8, 0.2))
# Out:
# Collecting split_folders
#   Downloading split_folders-0.4.3-py3-none-any.whl (7.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3
# Copying files: 59 files [00:09,  5.93 files/s]
# time: 13.3 s (started: 2021-10-26 08:30:05 +00:00)

# %%
base_dir = '/content/drive/MyDrive/Liveness Detection/Data'
train_dir = os.path.join(base_dir, 'train') ## Train Dataset
validation_dir = os.path.join(base_dir, 'val') ## Validation Dataset
# Out:
# time: 2.23 ms (started: 2021-10-26 08:31:45 +00:00)

# %%
os.listdir('/content/drive/MyDrive/Liveness Detection/Data/train')
# Out:
# ['Spoof', 'Live']
# time: 9.43 ms (started: 2021-10-26 08:31:47 +00:00)

# %%
os.listdir('/content/drive/MyDrive/Liveness Detection/Data/val')
# Out:
# ['Spoof', 'Live']
# time: 7.15 ms (started: 2021-10-26 08:31:48 +00:00)

# %%
train_live_dir = os.path.join(train_dir, 'Live')
train_spoof_dir = os.path.join(train_dir, 'Spoof')

validation_live_dir = os.path.join(validation_dir, 'Live')
validation_spoof_dir = os.path.join(validation_dir, 'Spoof')
# Out:
# time: 3.15 ms (started: 2021-10-26 08:32:08 +00:00)

# %% [markdown]
# ## Check Train and Test Data

# %% [markdown]
# **Train Data**

# %%
total_size_train = (
    len(os.listdir('/content/drive/MyDrive/Liveness Detection/Data/train/Live')) + 
    len(os.listdir('/content/drive/MyDrive/Liveness Detection/Data/train/Spoof'))
)
print('Total Training Data is : {}'.format(total_size_train))
# Out:
# Total Training Data is : 47
# time: 9.63 ms (started: 2021-10-26 08:32:10 +00:00)

# %% [markdown]
# **Test Data**

# %%
total_size_test = (
    len(os.listdir('/content/drive/MyDrive/Liveness Detection/Data/val/Live')) + 
    len(os.listdir('/content/drive/MyDrive/Liveness Detection/Data/val/Spoof'))
)
print('Total Testing Data is : {}'.format(total_size_test))
# Out:
# Total Testing Data is : 12
# time: 6.6 ms (started: 2021-10-26 08:32:15 +00:00)

# %% [markdown]
# ## Image Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.2,
    horizontal_flip = True,
    shear_range = 0.2,
    zoom_range = 0.2,
    fill_mode = 'nearest'
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150, 150),
    #batch_size = 128,
    class_mode = 'binary'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size = (150, 150),
    #batch_size = 128,
    class_mode = 'binary'
)
# Out:
# Found 47 images belonging to 2 classes.
# Found 12 images belonging to 2 classes.
# time: 221 ms (started: 2021-10-26 08:32:15 +00:00)

# %% [markdown]
# ## Construct Model Using CNN

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# time: 92.8 ms (started: 2021-10-26 08:32:16 +00:00)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               3211776
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________
# time: 15 ms (started: 2021-10-26 08:32:16 +00:00)

# %%
model.compile(
    loss = 'binary_crossentropy',
    optimizer = 'Adam',
    metrics = ['accuracy']
)
# Out:
# time: 10.6 ms (started: 2021-10-26 08:32:16 +00:00)

# %%
history = model.fit(
    train_generator,
    epochs = 50,
    #callbacks = [reduce_LR, stop_early],
    validation_data = validation_generator,
    verbose = 1
)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 2s 520ms/step - loss: 0.8511 - accuracy: 0.3191 - val_loss: 0.7571 - val_accuracy: 0.5000
# Epoch 2/50
# 2/2 [==============================] - 1s 293ms/step - loss: 0.7354 - accuracy: 0.4894 - val_loss: 0.6799 - val_accuracy: 0.5000
# Epoch 3/50
# 2/2 [==============================] - 1s 290ms/step - loss: 0.6605 - accuracy: 0.4894 - val_loss: 0.6259 - val_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 1s 525ms/step - loss: 0.5958 - accuracy: 0.7447 - val_loss: 0.5492 - val_accuracy: 0.5833
# Epoch 5/50
# 2/2 [==============================] - 1s 296ms/step - loss: 0.4677 - accuracy: 0.8936 - val_loss: 0.3858 - val_accuracy: 0.9167
# Epoch 6/50
# 2/2 [==============================] - 1s 518ms/step - loss: 0.3189 - accuracy: 0.9362 - val_loss: 0.6412 - val_accuracy: 0.6667
# Epoch 7/50
# 2/2 [==============================] - 1s 296ms/step - loss: 0.4194 - accuracy: 0.8723 - val_loss: 0.3963 - val_accuracy: 0.8333
# Epoch 8/50
# 2/2 [==============================] - 1s 291ms/step - loss: 0.2253 - accuracy: 0.9149 - val_loss: 0.5673 - val_accuracy: 0.8333
# Epoch 9/50
# 2/2 [==============================] - 1s 528ms/step - loss: 0.4641 - accuracy: 0.7872 - val_loss: 0.1324 - val_accuracy: 0.9167
# Epoch 10/50
# 2/2 [==============================] - 1s 307ms/step - loss: 0.2118 - accuracy: 0.9149 - val_loss: 0.5109 - val_accuracy: 0.8333
# Epoch 11/50
# 2/2 [==============================] - 1s 276ms/step - loss: 0.2406 - accuracy: 0.8723 - val_loss: 0.1542 - val_accuracy: 0.9167
# Epoch 12/50
# 2/2 [==============================] - 1s 524ms/step - loss: 0.2075 - accuracy: 0.9362 - val_loss: 0.3196 - val_accuracy: 0.8333
# Epoch 13/50
# 2/2 [==============================] - 1s 299ms/step - loss: 0.1756 - accuracy: 0.9787 - val_loss: 0.1215 - val_accuracy: 0.9167
# Epoch 14/50
# 2/2 [==============================] - 1s 520ms/step - loss: 0.1385 - accuracy: 0.9574 - val_loss: 0.2460 - val_accuracy: 0.8333
# Epoch 15/50
# 2/2 [==============================] - 1s 506ms/step - loss: 0.2126 - accuracy: 0.9362 - val_loss: 0.2484 - val_accuracy: 0.8333
# Epoch 16/50
# 2/2 [==============================] - 1s 293ms/step - loss: 0.2516 - accuracy: 0.8936 - val_loss: 0.2114 - val_accuracy: 0.9167
# Epoch 17/50
# 2/2 [==============================] - 1s 298ms/step - loss: 0.1674 - accuracy: 0.9574 - val_loss: 0.6188 - val_accuracy: 0.7500
# Epoch 18/50
# 2/2 [==============================] - 1s 283ms/step - loss: 0.2492 - accuracy: 0.9362 - val_loss: 0.2110 - val_accuracy: 0.9167
# Epoch 19/50
# 2/2 [==============================] - 1s 512ms/step - loss: 0.1114 - accuracy: 0.9574 - val_loss: 0.1603 - val_accuracy: 0.9167
# Epoch 20/50
# 2/2 [==============================] - 1s 309ms/step - loss: 0.1300 - accuracy: 0.9787 - val_loss: 0.2416 - val_accuracy: 0.8333
# Epoch 21/50
# 2/2 [==============================] - 1s 635ms/step - loss: 0.2451 - accuracy: 0.8936 - val_loss: 0.1776 - val_accuracy: 0.9167
# Epoch 22/50
# 2/2 [==============================] - 1s 301ms/step - loss: 0.1151 - accuracy: 0.9574 - val_loss: 0.1818 - val_accuracy: 0.9167
# Epoch 23/50
# 2/2 [==============================] - 1s 290ms/step - loss: 0.0848 - accuracy: 0.9787 - val_loss: 0.3708 - val_accuracy: 0.8333
# Epoch 24/50
# 2/2 [==============================] - 1s 519ms/step - loss: 0.2245 - accuracy: 0.9574 - val_loss: 0.0854 - val_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 1s 531ms/step - loss: 0.1813 - accuracy: 0.9149 - val_loss: 0.1443 - val_accuracy: 0.9167
# Epoch 26/50
# 2/2 [==============================] - 1s 517ms/step - loss: 0.1693 - accuracy: 0.9149 - val_loss: 0.0860 - val_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 1s 516ms/step - loss: 0.1190 - accuracy: 0.9362 - val_loss: 0.1583 - val_accuracy: 0.9167
# Epoch 28/50
# 2/2 [==============================] - 1s 525ms/step - loss: 0.1024 - accuracy: 0.9787 - val_loss: 0.4594 - val_accuracy: 0.8333
# Epoch 29/50
# 2/2 [==============================] - 1s 523ms/step - loss: 0.1757 - accuracy: 0.9362 - val_loss: 0.2964 - val_accuracy: 0.9167
# Epoch 30/50
# 2/2 [==============================] - 1s 295ms/step - loss: 0.1253 - accuracy: 0.9574 - val_loss: 0.0701 - val_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 1s 277ms/step - loss: 0.1359 - accuracy: 0.9362 - val_loss: 0.1527 - val_accuracy: 0.9167
# Epoch 32/50
# 2/2 [==============================] - 1s 296ms/step - loss: 0.1707 - accuracy: 0.9574 - val_loss: 0.0528 - val_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 1s 292ms/step - loss: 0.0888 - accuracy: 0.9787 - val_loss: 0.3225 - val_accuracy: 0.9167
# Epoch 34/50
# 2/2 [==============================] - 1s 280ms/step - loss: 0.1098 - accuracy: 0.9574 - val_loss: 0.7960 - val_accuracy: 0.7500
# Epoch 35/50
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0796 - accuracy: 0.9787 - val_loss: 0.3927 - val_accuracy: 0.9167
# Epoch 36/50
# 2/2 [==============================] - 1s 303ms/step - loss: 0.1380 - accuracy: 0.9787 - val_loss: 0.0412 - val_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 1s 511ms/step - loss: 0.1019 - accuracy: 0.9574 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0580 - accuracy: 0.9574 - val_loss: 0.4301 - val_accuracy: 0.9167
# Epoch 39/50
# 2/2 [==============================] - 1s 293ms/step - loss: 0.0333 - accuracy: 1.0000 - val_loss: 1.0495 - val_accuracy: 0.7500
# Epoch 40/50
# 2/2 [==============================] - 1s 514ms/step - loss: 0.1916 - accuracy: 0.9787 - val_loss: 0.4395 - val_accuracy: 0.9167
# Epoch 41/50
# 2/2 [==============================] - 1s 283ms/step - loss: 0.0848 - accuracy: 0.9787 - val_loss: 0.0220 - val_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 1s 286ms/step - loss: 0.2299 - accuracy: 0.9574 - val_loss: 0.1141 - val_accuracy: 0.9167
# Epoch 43/50
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0513 - accuracy: 0.9574 - val_loss: 0.0374 - val_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 1s 284ms/step - loss: 0.0833 - accuracy: 0.9574 - val_loss: 0.2961 - val_accuracy: 0.9167
# Epoch 45/50
# 2/2 [==============================] - 1s 269ms/step - loss: 0.1100 - accuracy: 0.9574 - val_loss: 0.4232 - val_accuracy: 0.8333
# Epoch 46/50
# 2/2 [==============================] - 1s 283ms/step - loss: 0.0545 - accuracy: 1.0000 - val_loss: 0.3734 - val_accuracy: 0.8333
# Epoch 47/50
# 2/2 [==============================] - 1s 298ms/step - loss: 0.1057 - accuracy: 0.9574 - val_loss: 0.0712 - val_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 1s 294ms/step - loss: 0.1366 - accuracy: 0.9149 - val_loss: 0.0524 - val_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 1s 520ms/step - loss: 0.0880 - accuracy: 0.9787 - val_loss: 0.1804 - val_accuracy: 0.9167
# Epoch 50/50
# 2/2 [==============================] - 1s 285ms/step - loss: 0.0342 - accuracy: 0.9787 - val_loss: 0.2581 - val_accuracy: 0.9167
# time: 40 s (started: 2021-10-26 08:32:16 +00:00)

# %%
model_1 = tf.keras.models.Sequential([
# first CONV => RELU => CONV => RELU => POOL layer set                                   
  tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding="same", input_shape=(150, 150, 3)),
  #tf.keras.layers.BatchNormalization(1),
  tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding="same"),
  #tf.keras.layers.BatchNormalization(1),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Dropout(0.25),

# second CONV => RELU => CONV => RELU => POOL layer set
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding="same"),
  #tf.keras.layers.BatchNormalization(1),
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding="same"),
  #tf.keras.layers.BatchNormalization(1),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Dropout(0.25),

# first (and only) set of FC => RELU layers
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(64, activation='relu'),
  #tf.keras.layers.BatchNormalization(1),
  tf.keras.layers.Dropout(0.5), 

# softmax classifier
  tf.keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# time: 108 ms (started: 2021-10-26 08:32:56 +00:00)

# %%
model_1.compile(
    loss = 'binary_crossentropy',
    optimizer = 'Adam',
    metrics = ['accuracy']
)
# Out:
# time: 10 ms (started: 2021-10-26 08:32:56 +00:00)

# %%
history_1 = model_1.fit(
    train_generator,
    epochs = 50,
    #callbacks = [reduce_LR, stop_early],
    validation_data = validation_generator,
    verbose = 1
)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 3s 914ms/step - loss: 1.0761 - accuracy: 0.4468 - val_loss: 1.0823 - val_accuracy: 0.5000
# Epoch 2/50
# 2/2 [==============================] - 1s 510ms/step - loss: 1.6227 - accuracy: 0.4894 - val_loss: 0.6570 - val_accuracy: 0.5000
# Epoch 3/50
# 2/2 [==============================] - 1s 514ms/step - loss: 0.7076 - accuracy: 0.5957 - val_loss: 0.6584 - val_accuracy: 0.5000
# Epoch 4/50
# 2/2 [==============================] - 1s 514ms/step - loss: 0.7905 - accuracy: 0.5319 - val_loss: 0.6555 - val_accuracy: 0.5000
# Epoch 5/50
# 2/2 [==============================] - 1s 537ms/step - loss: 0.6966 - accuracy: 0.5106 - val_loss: 0.6549 - val_accuracy: 0.5000
# Epoch 6/50
# 2/2 [==============================] - 1s 525ms/step - loss: 0.6579 - accuracy: 0.7021 - val_loss: 0.6451 - val_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 1s 272ms/step - loss: 0.6466 - accuracy: 0.7021 - val_loss: 0.6308 - val_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 1s 529ms/step - loss: 0.6439 - accuracy: 0.6170 - val_loss: 0.6091 - val_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 1s 545ms/step - loss: 0.5901 - accuracy: 0.7872 - val_loss: 0.5683 - val_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 1s 541ms/step - loss: 0.5669 - accuracy: 0.7660 - val_loss: 0.5203 - val_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 1s 543ms/step - loss: 0.5129 - accuracy: 0.7872 - val_loss: 0.4505 - val_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 1s 285ms/step - loss: 0.4716 - accuracy: 0.7872 - val_loss: 0.3679 - val_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 1s 544ms/step - loss: 0.3898 - accuracy: 0.9149 - val_loss: 0.3116 - val_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 1s 282ms/step - loss: 0.3253 - accuracy: 0.9149 - val_loss: 0.2190 - val_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 1s 532ms/step - loss: 0.3344 - accuracy: 0.9362 - val_loss: 0.1542 - val_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 1s 291ms/step - loss: 0.2685 - accuracy: 0.9362 - val_loss: 0.1419 - val_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 1s 529ms/step - loss: 0.2219 - accuracy: 0.9362 - val_loss: 0.0857 - val_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 1s 528ms/step - loss: 0.2582 - accuracy: 0.9149 - val_loss: 0.0581 - val_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 1s 282ms/step - loss: 0.2039 - accuracy: 0.9149 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 1s 291ms/step - loss: 0.2262 - accuracy: 0.9149 - val_loss: 0.0470 - val_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 1s 522ms/step - loss: 0.1756 - accuracy: 0.9149 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 1s 528ms/step - loss: 0.2514 - accuracy: 0.9149 - val_loss: 0.0442 - val_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 1s 534ms/step - loss: 0.2328 - accuracy: 0.9574 - val_loss: 0.0889 - val_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 1s 295ms/step - loss: 0.1638 - accuracy: 0.9149 - val_loss: 0.1367 - val_accuracy: 0.9167
# Epoch 25/50
# 2/2 [==============================] - 1s 528ms/step - loss: 0.1628 - accuracy: 0.9362 - val_loss: 0.0499 - val_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 1s 280ms/step - loss: 0.1417 - accuracy: 0.9574 - val_loss: 0.1299 - val_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 1s 278ms/step - loss: 0.2042 - accuracy: 0.8723 - val_loss: 0.0505 - val_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 1s 286ms/step - loss: 0.2211 - accuracy: 0.9574 - val_loss: 0.1187 - val_accuracy: 0.9167
# Epoch 29/50
# 2/2 [==============================] - 1s 278ms/step - loss: 0.1776 - accuracy: 0.9362 - val_loss: 0.1480 - val_accuracy: 0.9167
# Epoch 30/50
# 2/2 [==============================] - 1s 289ms/step - loss: 0.2136 - accuracy: 0.9362 - val_loss: 0.0556 - val_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 1s 279ms/step - loss: 0.1301 - accuracy: 0.9574 - val_loss: 0.0561 - val_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 1s 526ms/step - loss: 0.1134 - accuracy: 0.9574 - val_loss: 0.0847 - val_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 1s 558ms/step - loss: 0.1724 - accuracy: 0.9362 - val_loss: 0.0379 - val_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 1s 291ms/step - loss: 0.1839 - accuracy: 0.9362 - val_loss: 0.0569 - val_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 1s 272ms/step - loss: 0.2311 - accuracy: 0.9149 - val_loss: 0.0533 - val_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 1s 280ms/step - loss: 0.1458 - accuracy: 0.9149 - val_loss: 0.0379 - val_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 1s 276ms/step - loss: 0.1623 - accuracy: 0.9362 - val_loss: 0.0638 - val_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 1s 531ms/step - loss: 0.1130 - accuracy: 0.9574 - val_loss: 0.0707 - val_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 1s 295ms/step - loss: 0.1009 - accuracy: 0.9787 - val_loss: 0.0467 - val_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 1s 546ms/step - loss: 0.1130 - accuracy: 0.9574 - val_loss: 0.0367 - val_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 1s 286ms/step - loss: 0.1412 - accuracy: 0.9787 - val_loss: 0.0322 - val_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 1s 518ms/step - loss: 0.1666 - accuracy: 0.9787 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 1s 296ms/step - loss: 0.0728 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 1s 534ms/step - loss: 0.0911 - accuracy: 0.9787 - val_loss: 0.0349 - val_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 1s 532ms/step - loss: 0.0625 - accuracy: 0.9787 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 1s 617ms/step - loss: 0.0696 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 1s 291ms/step - loss: 0.1082 - accuracy: 0.9574 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 1s 546ms/step - loss: 0.1180 - accuracy: 0.9574 - val_loss: 0.0415 - val_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 1s 524ms/step - loss: 0.1970 - accuracy: 0.9362 - val_loss: 0.0187 - val_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0705 - accuracy: 0.9574 - val_loss: 0.0228 - val_accuracy: 1.0000
# time: 40.4 s (started: 2021-10-26 08:32:56 +00:00)

# %% [markdown]
# ## Plot Model History

# %%
import matplotlib.pyplot as plt

def plot_accuracy(history):
  plt.figure(figsize=(18,5))
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  epochs = range(len(acc))
  plot_acc = plt.plot(epochs, acc, 'red', label='Training Accuracy')
  plot_val_acc = plt.plot(epochs, val_acc, 'blue', label='Validation Accuracy')
  plt.xlabel('Epoch', fontsize=15)
  plt.ylabel('Accuracy', fontsize=15)
  plt.title('Training and Validation Accuracy', fontsize=25)
  plt.legend(bbox_to_anchor=(1,1), loc='best')
  plt.grid()
  plt.show()

def plot_loss(history):
  plt.figure(figsize=(18,5))
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs = range(len(loss))
  plot_loss = plt.plot(epochs, loss, 'red', label='Training Loss')
  plot_val_loss = plt.plot(epochs, val_loss, 'blue', label='Validation Loss')
  plt.xlabel('Epoch', fontsize=15)
  plt.ylabel('Loss', fontsize=15)
  plt.title('Training and Validation Loss', fontsize=25)
  plt.legend(bbox_to_anchor=(1,1), loc='best')
  plt.grid()
  plt.show()
# Out:
# time: 26.6 ms (started: 2021-10-26 08:33:36 +00:00)

# %%
plot_accuracy(history)
# Out:
# time: 307 ms (started: 2021-10-26 08:33:36 +00:00)

# %%
plot_accuracy(history_1)
# Out:
# time: 484 ms (started: 2021-10-26 08:33:37 +00:00)

# %%
plot_loss(history)
# Out:
# time: 253 ms (started: 2021-10-26 08:33:37 +00:00)

# %%
plot_loss(history_1)
# Out:
# time: 277 ms (started: 2021-10-26 08:33:37 +00:00)
